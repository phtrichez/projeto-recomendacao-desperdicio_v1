# %% [markdown]
# # 01 - EDA Food.com
#
# Este notebook executa a análise exploratória da base Food.com Recipes and Interactions e salva os resultados em `results/`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

DATA_PATH = r"C:\\Mackenzie Ciencia Dados\\4 Semestre\\Projeto aplicado 3\\archive.zip"
RESULTS_DIR = PROJECT_ROOT / "results"

# %%
from eda import run_eda

outputs = run_eda(DATA_PATH, RESULTS_DIR)
outputs["resumo"]

# %%
outputs["distribuicao_avaliacoes"]

# %%
outputs["top_mais_avaliadas"]

# %%
outputs["top_melhor_media"]
