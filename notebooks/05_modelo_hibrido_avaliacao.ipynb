# %% [markdown]
# # 05 - Modelo hibrido e avaliacao
#
# Executa a avaliacao top-k dos modelos de popularidade, conteudo, SVD e hibrido.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from evaluation import run_ranking_evaluation

DATA_PATH = r'C:\\Mackenzie Ciencia Dados\\4 Semestre\\Projeto aplicado 3\\archive.zip'
metricas = run_ranking_evaluation(DATA_PATH, PROJECT_ROOT / 'results', k=10)
metricas
