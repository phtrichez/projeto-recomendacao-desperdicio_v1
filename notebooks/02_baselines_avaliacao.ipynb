# %% [markdown]
# # 02 - Baselines de avaliação
#
# Este notebook avalia três baselines simples com divisão treino/teste 80/20 e salva `results/metricas_baseline.csv`.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.append(str(PROJECT_ROOT / "src"))

DATA_PATH = r"C:\\Mackenzie Ciencia Dados\\4 Semestre\\Projeto aplicado 3\\archive.zip"
RESULTS_DIR = PROJECT_ROOT / "results"

# %%
from evaluation import run_baseline_evaluation

metrics = run_baseline_evaluation(DATA_PATH, RESULTS_DIR, test_size=0.2, random_state=42)
metrics
