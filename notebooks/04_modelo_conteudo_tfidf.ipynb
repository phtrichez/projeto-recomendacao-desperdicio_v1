# %% [markdown]
# # 04 - Modelo baseado em conteudo com TF-IDF
#
# Cria perfis de usuario a partir das receitas bem avaliadas no treino.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from data_loader import preparar_amostra_modelagem, carregar_receitas, dividir_treino_teste_por_usuario
from content_based import ContentBasedRecommender

DATA_PATH = r'C:\\Mackenzie Ciencia Dados\\4 Semestre\\Projeto aplicado 3\\archive.zip'
amostra = preparar_amostra_modelagem(DATA_PATH, PROJECT_ROOT / 'results')
receitas = carregar_receitas(DATA_PATH, recipe_ids=amostra['recipe_id'].unique())
treino, teste = dividir_treino_teste_por_usuario(amostra)
modelo = ContentBasedRecommender(min_rating_perfil=4).fit(treino, receitas)
usuario = int(treino['user_id'].iloc[0])
modelo.recomendar_usuario(usuario, k=10)
